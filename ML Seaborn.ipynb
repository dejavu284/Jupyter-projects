# %% [markdown]
# # Визуализация с помощью библиотеки seaborn
# ## displot
# ## scatterplot
# ## countplot
# ##
# ##

# %%
import seaborn as sns
import pandas as pd
pd.options.mode.chained_assignment = None
df=pd.read_csv(r'C:\Users\Я\Desktop\читы жизнь\Study\Programming\0_Jupyter\students.csv',delimiter=',')

# %%
df[df['Children number']==1024]
# Out:
#      Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 115   17     175         41              0           2004            152
#
#      Russian rating  Maths rating  Physics rating  Computer science rating  \
# 115              96            80               0                       83
#
#      ...  Social network duration min  Chocolate  City population  \
# 115  ...                         1000     КитКат              1.0
#
#      Strange people        Your insitute          Brother-sister  \
# 115          СоцГум  Математический и ИТ  нет ни брата ни сестры
#
#                           Plane seat  MIddle and index finger  \
# 115  У окна (пардон: у иллюминатора)                        3
#
#      Middle and ring finger  Middle and little finger
# 115                     2.0                       5.0
#
# [1 rows x 48 columns]

# %%
df_clean=df.drop(labels=[115],axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
df_clean[df_clean['City population']==8000000]
df_clean=df_clean.drop([180],axis=0)

# %% [markdown]
# # Визуализация по одной координате
# ## displot

# %%
sns.displot(data=df_clean, x='City population', kind="kde")

# %% [markdown]
# # Визуализация облака точек
# ## scatterplot

# %%
sns.scatterplot(data=df_clean, x='Weight', y='Growth', hue='Animal')
# Out:
# <AxesSubplot: xlabel='Weight', ylabel='Growth'>

# %% [markdown]
# # Визуализация категориальных величин
# ## countplot

# %%
sns.countplot(data=df,x='Sex',hue='Animal')
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='count'>

# %%
df_NewCat=df_clean[['Age','Growth','Weight','Shoe size','Sex']]
df_NewCat
# Out:
#      Age  Growth  Weight  Shoe size      Sex
# 0     20     170    64.0         40  женский
# 1     22     191    73.0         43  мужской
# 2     21     172    60.0         41  мужской
# 3     19     168    59.0         38  женский
# 4     23     159    57.0         36  женский
# ..   ...     ...     ...        ...      ...
# 181   23     168    59.0         39  женский
# 182   19     169    43.0         38  женский
# 183   18     161    51.0         37  женский
# 184   19     169    62.0         41  женский
# 185   18     164    54.0         39  женский
#
# [184 rows x 5 columns]

# %%
sns.pairplot(df_NewCat,hue='Sex')
