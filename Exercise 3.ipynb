# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\Я\Desktop\читы жизнь\Study\Programming\0_Jupyter\students.csv',delimiter=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
df_cut=df[['Age','Growth','Weight']]

# %%
df_cut
# Out:
#      Age  Growth  Weight
# 0     20     170    64.0
# 1     22     191    73.0
# 2     21     172    60.0
# 3     19     168    59.0
# 4     23     159    57.0
# ..   ...     ...     ...
# 181   23     168    59.0
# 182   19     169    43.0
# 183   18     161    51.0
# 184   19     169    62.0
# 185   18     164    54.0
#
# [186 rows x 3 columns]

# %% [markdown]
# # Сортировка
# По одному столбцу

# %%
df_cut.sort_values(by='Age', ascending=True)
# Out:
#      Age  Growth  Weight  Mass index
# 126   17     168    71.0   25.155896
# 115   17     175    72.0   23.510204
# 185   18     164    54.0   20.077335
# 133   18     177    80.0   25.535446
# 127   18     165    46.0   16.896235
# ..   ...     ...     ...         ...
# 82    27     168    58.0   20.549887
# 173   29     176    70.0   22.598140
# 99    31     165    53.0   19.467401
# 63    35     180    78.0   24.074074
# 81    55     160     3.0    1.171875
#
# [186 rows x 4 columns]

# %% [markdown]
# # Сортировка
# По нескольким столбцам

# %%
df_cut.sort_values(['Age','Growth','Weight'], ascending=[False, False,False])
# Out:
#      Age  Growth  Weight  Mass index
# 81    55     160     3.0    1.171875
# 63    35     180    78.0   24.074074
# 99    31     165    53.0   19.467401
# 173   29     176    70.0   22.598140
# 82    27     168    58.0   20.549887
# ..   ...     ...     ...         ...
# 47    18     159     NaN         NaN
# 94    18     158    53.0   21.230572
# 118   18     157    59.0   23.936062
# 115   17     175    72.0   23.510204
# 126   17     168    71.0   25.155896
#
# [186 rows x 4 columns]

# %% [markdown]
# # Добавление столбца ||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
df_cut['Mass indexx']=df_cut['Weight']/((df_cut['Growth']/100)**2)
# Out:
# C:\Users\Я\AppData\Local\Temp\ipykernel_14356\50909250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cut['Mass indexx']=df_cut['Weight']/((df_cut['Growth']/100)**2)

# %%
new_df=df_cut.sort_values(['Mass index'])

# %%
new_df.iloc[1]
# Out:
# Age            22.000000
# Growth        178.000000
# Weight          7.000000
# Mass index      2.209317
# Name: 114, dtype: float64

# %%
new_df.head(10)
# Out:
#      Age  Growth  Weight  Mass index
# 81    55     160     3.0    1.171875
# 114   22     178     7.0    2.209317
# 182   19     169    43.0   15.055495
# 5     18     177    50.0   15.959654
# 139   20     170    47.0   16.262976
# 27    19     193    61.0   16.376279
# 43    18     170    48.0   16.608997
# 127   18     165    46.0   16.896235
# 6     18     180    55.0   16.975309
# 92    20     164    46.0   17.102915

# %% [markdown]
# # Удаление столбца ||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
df_cut.drop(columns=['Weight','Mass index'])
# Out:
#      Age  Growth
# 0     20     170
# 1     22     191
# 2     21     172
# 3     19     168
# 4     23     159
# ..   ...     ...
# 181   23     168
# 182   19     169
# 183   18     161
# 184   19     169
# 185   18     164
#
# [186 rows x 2 columns]
